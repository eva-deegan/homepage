# %% [markdown]
# <a href="https://colab.research.google.com/github/eva-deegan/homepage/blob/main/rest/REST_APIs_fill_in_the_blank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using REST APIs as data sources
#
# REST API stands for Representational State Transfer Application Programming Interface. It is a type of API that allows different systems to communicate over the internet using standard HTTP methods.
#
# * Data is everywhere and it is generated constantly
# * The number of data sources is amazingly huge
# * Datasets are huge and can be used in many ways
#
# * We may do amazing things using data made available by third-party:
#     - https://developer.walmartlabs.com/docs
#     - https://developer.spotify.com/documentation/web-api/
#     - https://earthquake.usgs.gov/fdsnws/event/1/
#
#
# We will have a nice and brief overview about how to consume data from REST APIs, mainly focusing on **JSON**.
#
# this will allow us to work with "live" data

# %% [markdown]
# ### What is an API?
#
# **Application Programming Interface** defines the methods for one software program to interact with the other.
#
# In the case of this lecture, we are dealing with a REST API, which sends data over a network: one type of Web service.
#
# When we want to receive data from an Web service, we need to make a `request` to this service. When the server receives this request, it sends a `response`.
#
# ![request.png](https://github.com/kylewinfree/inf502-fall2025/blob/main/rest/request.png?raw=1)

# %% [markdown]
# There are different types of requests.
#
# In our case we will use a `GET`, which is used to retrieve data. This is the type of request we use to collect data.
#
# A response from the API contains 2 things (among others):
# * response code
# * response data
#
# To make a request, we use:

# %%
import requests
response = requests.get('http://www.nau.edu/')
type(response)
# Out:
# requests.models.Response

# %% [markdown]
# The `request.get(URL)` returns an object Response, which provides, among other things, the response code.

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# The most common codes are:
# * 200: Everything went okay, and the result has been returned (if any).
# * 301: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
# * 400: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
# * 401: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t send the right credentials to access an API.
# * 403: The resource you’re trying to access is forbidden: you don’t have the right permissions to see it.
# * 404: The resource you tried to access wasn’t found on the server.
# * 503: The server is not ready to handle the request.
#
# More details about status codes list can be found [here](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status)

# %% [markdown]
# ### What about getting the data?
#
# First, read the documentation! Everytime you use an API, please read the documentation to understand how to use, the structure, etc.
#
# We will use the [Open Notify API](http://api.open-notify.org/), which gives access to data about the international space station.
#
# These APIs usually provide multiple endpoints, which are the ways we can interact with that service.
#
# Let's try a request and see how it goes:

# %%
response = requests.get("http://api.open-notify.org/astros.json")
print(response.status_code)
# Out:
# 200

# %%
type(response.content)
# Out:
# bytes

# %%
response.text
# Out:
# '{"people": [{"craft": "ISS", "name": "Oleg Kononenko"}, {"craft": "ISS", "name": "Nikolai Chub"}, {"craft": "ISS", "name": "Tracy Caldwell Dyson"}, {"craft": "ISS", "name": "Matthew Dominick"}, {"craft": "ISS", "name": "Michael Barratt"}, {"craft": "ISS", "name": "Jeanette Epps"}, {"craft": "ISS", "name": "Alexander Grebenkin"}, {"craft": "ISS", "name": "Butch Wilmore"}, {"craft": "ISS", "name": "Sunita Williams"}, {"craft": "Tiangong", "name": "Li Guangsu"}, {"craft": "Tiangong", "name": "Li Cong"}, {"craft": "Tiangong", "name": "Ye Guangfu"}], "number": 12, "message": "success"}'

# %%
response.json()
# Out:
# {'people': [{'craft': 'ISS', 'name': 'Oleg Kononenko'},
#   {'craft': 'ISS', 'name': 'Nikolai Chub'},
#   {'craft': 'ISS', 'name': 'Tracy Caldwell Dyson'},
#   {'craft': 'ISS', 'name': 'Matthew Dominick'},
#   {'craft': 'ISS', 'name': 'Michael Barratt'},
#   {'craft': 'ISS', 'name': 'Jeanette Epps'},
#   {'craft': 'ISS', 'name': 'Alexander Grebenkin'},
#   {'craft': 'ISS', 'name': 'Butch Wilmore'},
#   {'craft': 'ISS', 'name': 'Sunita Williams'},
#   {'craft': 'Tiangong', 'name': 'Li Guangsu'},
#   {'craft': 'Tiangong', 'name': 'Li Cong'},
#   {'craft': 'Tiangong', 'name': 'Ye Guangfu'}],
#  'number': 12,
#  'message': 'success'}

# %% [markdown]
# ### Working with JSON
# JSON stands for JavaScript Object Notation. It is a way to encode data structures that ensures that they are easily readable.
#
# JSON output look like Python something with *dictionaries, lists, strings* and *integers*. And it is...
#
# But, how to use it? Well, we used it in the last command.

# %%
import json

# %% [markdown]
# json has two main functions:
#
# * `json.dumps()` — Takes in a Python object and converts (dumps) to a string.
# * `json.loads()` — Takes a JSON string and converts (loads) to a Python object.
#
# The `dumps()` is particularly useful as we can use it to format the json, making it easier to understand the output

# %%
json_response = response.json()
formatted_json = json.dumps(json_response, sort_keys=True, indent=3) # indent is the number of spaces when making pretty

print(formatted_json)
# Out:
# {
#    "message": "success",
#    "number": 12,
#    "people": [
#       {
#          "craft": "ISS",
#          "name": "Oleg Kononenko"
#       },
#       {
#          "craft": "ISS",
#          "name": "Nikolai Chub"
#       },
#       {
#          "craft": "ISS",
#          "name": "Tracy Caldwell Dyson"
#       },
#       {
#          "craft": "ISS",
#          "name": "Matthew Dominick"
#       },
#       {
#          "craft": "ISS",
#          "name": "Michael Barratt"
#       },
#       {
#          "craft": "ISS",
#          "name": "Jeanette Epps"
#       },
#       {
#          "craft": "ISS",
#          "name": "Alexander Grebenkin"
#       },
#       {
#          "craft": "ISS",
#          "name": "Butch Wilmore"
#       },
#       {
#          "craft": "ISS",
#          "name": "Sunita Williams"
#       },
#       {
#          "craft": "Tiangong",
#          "name": "Li Guangsu"
#       },
#       {
#          "craft": "Tiangong",
#          "name": "Li Cong"
#       },
#       {
#          "craft": "Tiangong",
#          "name": "Ye Guangfu"
#       }
#    ]
# }

# %% [markdown]
# ### REST API with Query Parameters
# In some cases, it is possible to pass parameters to filter the output of the API.
#
# The https://earthquake.usgs.gov/fdsnws/event/1/query endpoint tells what are the earthquakes given a set of parameters. For example time, location, etc.
# More information here:
# https://earthquake.usgs.gov/fdsnws/event/1/#parameters
#
# In the example below, we show the earthquakes in January 2022 (`starttime` and `endtime`), with magnitude between 6 and 7 (`minmagnitude` and `maxmagnitude`).

# %%
import requests
import json
from datetime import datetime
# let's look at how this query is structured, and the output
response = requests.get("https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2022-01-01&endtime=2022-01-31&maxmagnitude=7&minmagnitude=6")
json_response = response.json()
formatted_json = json.dumps(json_response, sort_keys=False, indent=2)

print(formatted_json)
# Out:
# {
#   "type": "FeatureCollection",
#   "metadata": {
#     "generated": 1761687706000,
#     "url": "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2022-01-01&endtime=2022-01-31&maxmagnitude=7&minmagnitude=6",
#     "title": "USGS Earthquakes",
#     "status": 200,
#     "api": "1.14.1",
#     "count": 18
#   },
#   "features": [
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.5,
#         "place": "Kermadec Islands region",
#         "time": 1643424399588,
#         "updated": 1650045421040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gg3w",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gg3w&format=geojson",
#         "felt": 2,
#         "cdi": 7.1,
#         "mmi": 3.687,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 1,
#         "sig": 651,
#         "net": "us",
#         "code": "7000gg3w",
#         "ids": ",pt22029000,us7000gg3w,at00r6gae1,usauto7000gg3w,",
#         "sources": ",pt,us,at,usauto,",
#         "types": ",associate,dyfi,ground-failure,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 1.088,
#         "rms": 1.3,
#         "gap": 57,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.5 - Kermadec Islands region"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -176.7217,
#           -29.5642,
#           8
#         ]
#       },
#       "id": "us7000gg3w"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6,
#         "place": "281 km SW of Arenas, Panama",
#         "time": 1643368449293,
#         "updated": 1661111252328,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gfti",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gfti&format=geojson",
#         "felt": 7,
#         "cdi": 6.2,
#         "mmi": 3.444,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 558,
#         "net": "us",
#         "code": "7000gfti",
#         "ids": ",us7000gfti,usauto7000gfti,pt22028000,at00r6f37m,",
#         "sources": ",us,usauto,pt,at,",
#         "types": ",dyfi,ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 3.277,
#         "rms": 0.46,
#         "gap": 57,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.0 - 281 km SW of Arenas, Panama"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -82.5844,
#           5.4966,
#           8
#         ]
#       },
#       "id": "us7000gfti"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.2,
#         "place": "220 km WNW of Pangai, Tonga",
#         "time": 1643265605543,
#         "updated": 1649535549040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gfhb",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gfhb&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": 3.66,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 591,
#         "net": "us",
#         "code": "7000gfhb",
#         "ids": ",us7000gfhb,usauto7000gfhb,pt22027000,",
#         "sources": ",us,usauto,pt,",
#         "types": ",ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 5.069,
#         "rms": 0.51,
#         "gap": 45,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.2 - 220 km WNW of Pangai, Tonga"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -176.3135,
#           -19.0992,
#           6.2
#         ]
#       },
#       "id": "us7000gfhb"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6,
#         "place": "South Sandwich Islands region",
#         "time": 1643073873513,
#         "updated": 1659790208300,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gery",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gery&format=geojson",
#         "felt": 1,
#         "cdi": 2,
#         "mmi": 3.401,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 554,
#         "net": "us",
#         "code": "7000gery",
#         "ids": ",us7000gery,usauto7000gery,pt22025000,at00r68rx3,",
#         "sources": ",us,usauto,pt,at,",
#         "types": ",dyfi,ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 4.586,
#         "rms": 0.84,
#         "gap": 27,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.0 - South Sandwich Islands region"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -28.7839,
#           -55.3696,
#           11
#         ]
#       },
#       "id": "us7000gery"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.2,
#         "place": "71 km S of Unalaska, Alaska",
#         "time": 1642828624896,
#         "updated": 1704688326084,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000ge5q",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000ge5q&format=geojson",
#         "felt": 23,
#         "cdi": 3.9,
#         "mmi": 5.308,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 1,
#         "sig": 600,
#         "net": "us",
#         "code": "7000ge5q",
#         "ids": ",at00r63iof,us7000ge5q,usauto7000ge5q,pt22022001,ak02210gwcyq,",
#         "sources": ",at,us,usauto,pt,ak,",
#         "types": ",dyfi,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 0.566,
#         "rms": 0.94,
#         "gap": 95,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.2 - 71 km S of Unalaska, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -166.682,
#           53.2402,
#           29
#         ]
#       },
#       "id": "us7000ge5q"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6,
#         "place": "232 km SE of Sarangani, Philippines",
#         "time": 1642818373323,
#         "updated": 1649535526040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000ge38",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000ge38&format=geojson",
#         "felt": 7,
#         "cdi": 4.1,
#         "mmi": 5.849,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 557,
#         "net": "us",
#         "code": "7000ge38",
#         "ids": ",us7000ge38,usauto7000ge38,pt22022000,at00r63aru,",
#         "sources": ",us,usauto,pt,at,",
#         "types": ",dyfi,ground-failure,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 2.966,
#         "rms": 0.96,
#         "gap": 34,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.0 - 232 km SE of Sarangani, Philippines"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           126.6596,
#           3.6724,
#           21
#         ]
#       },
#       "id": "us7000ge38"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.3,
#         "place": "27 km SSE of Saiki, Japan",
#         "time": 1642781317210,
#         "updated": 1676044263910,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gdwz",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gdwz&format=geojson",
#         "felt": 106,
#         "cdi": 7.5,
#         "mmi": 6.516,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 1,
#         "sig": 690,
#         "net": "us",
#         "code": "7000gdwz",
#         "ids": ",at00r62i6f,us7000gdwz,usauto7000gdwz,pt22021000,",
#         "sources": ",at,us,usauto,pt,",
#         "types": ",dyfi,ground-failure,impact-link,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 1.813,
#         "rms": 1.11,
#         "gap": 25,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.3 - 27 km SSE of Saiki, Japan"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           132.0386,
#           32.7282,
#           39
#         ]
#       },
#       "id": "us7000gdwz"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.1,
#         "place": "74 km WSW of Panguna, Papua New Guinea",
#         "time": 1642337528025,
#         "updated": 1648834813040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gcfv",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gcfv&format=geojson",
#         "felt": null,
#         "cdi": null,
#         "mmi": 2.819,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 572,
#         "net": "us",
#         "code": "7000gcfv",
#         "ids": ",us7000gcfv,usauto7000gcfv,pt22016000,at00r5szqy,",
#         "sources": ",us,usauto,pt,at,",
#         "types": ",ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 3.469,
#         "rms": 0.66,
#         "gap": 20,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.1 - 74 km WSW of Panguna, Papua New Guinea"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           154.8224,
#           -6.4492,
#           379
#         ]
#       },
#       "id": "us7000gcfv"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.6,
#         "place": "80 km SW of Labuan, Indonesia",
#         "time": 1642151141461,
#         "updated": 1736043105617,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gbu4",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gbu4&format=geojson",
#         "felt": 157,
#         "cdi": 7.7,
#         "mmi": 6.2,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 791,
#         "net": "us",
#         "code": "7000gbu4",
#         "ids": ",us7000gbu4,usauto7000gbu4,pt22014000,at00r5ozxj,",
#         "sources": ",us,usauto,pt,at,",
#         "types": ",dyfi,ground-failure,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 2.418,
#         "rms": 0.54,
#         "gap": 22,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.6 - 80 km SW of Labuan, Indonesia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           105.2887,
#           -6.86,
#           33
#         ]
#       },
#       "id": "us7000gbu4"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.6,
#         "place": "53 km SE of Nikolski, Alaska",
#         "time": 1641904772454,
#         "updated": 1703738035254,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gawk",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gawk&format=geojson",
#         "felt": 5,
#         "cdi": 7.9,
#         "mmi": 5.381,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 1,
#         "sig": 674,
#         "net": "us",
#         "code": "7000gawk",
#         "ids": ",us7000gawk,at00r5jpu0,pt22011002,usauto7000gawk,ak022ieagfj,",
#         "sources": ",us,at,pt,usauto,ak,",
#         "types": ",dyfi,general-text,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,trump-origin,",
#         "nst": null,
#         "dmin": 0.507,
#         "rms": 0.52,
#         "gap": 49,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.6 - 53 km SE of Nikolski, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -168.3275,
#           52.5791,
#           19
#         ]
#       },
#       "id": "us7000gawk"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.8,
#         "place": "100 km SE of Nikolski, Alaska",
#         "time": 1641900943674,
#         "updated": 1703738156061,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gavu",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gavu&format=geojson",
#         "felt": 28,
#         "cdi": 6.5,
#         "mmi": 6.389,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 1,
#         "sig": 730,
#         "net": "us",
#         "code": "7000gavu",
#         "ids": ",at00r5jmvn,ak022ido6wm,us7000gavu,pt22011001,usauto7000gavu,",
#         "sources": ",at,ak,us,pt,usauto,",
#         "types": ",dyfi,general-text,ground-failure,impact-link,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 0.92,
#         "rms": 0.56,
#         "gap": 61,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.8 - 100 km SE of Nikolski, Alaska"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -167.7554,
#           52.3415,
#           20
#         ]
#       },
#       "id": "us7000gavu"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.6,
#         "place": "48 km WNW of P\u00f3lis, Cyprus",
#         "time": 1641863268064,
#         "updated": 1654661183087,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gaqu",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gaqu&format=geojson",
#         "felt": 486,
#         "cdi": 6.3,
#         "mmi": 5.555,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 976,
#         "net": "us",
#         "code": "7000gaqu",
#         "ids": ",us7000gaqu,usauto7000gaqu,at00r5itt0,pt22011000,",
#         "sources": ",us,usauto,at,pt,",
#         "types": ",dyfi,ground-failure,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 1.168,
#         "rms": 0.71,
#         "gap": 21,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.6 - 48 km WNW of P\u00f3lis, Cyprus"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           31.9435,
#           35.2267,
#           21
#         ]
#       },
#       "id": "us7000gaqu"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.2,
#         "place": "south of the Kermadec Islands",
#         "time": 1641773190834,
#         "updated": 1659796917275,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gag3",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gag3&format=geojson",
#         "felt": 1,
#         "cdi": 4.1,
#         "mmi": 4.622,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 592,
#         "net": "us",
#         "code": "7000gag3",
#         "ids": ",us7000gag3,at00r5gwau,pt22010000,",
#         "sources": ",us,at,pt,",
#         "types": ",dyfi,ground-failure,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 4.892,
#         "rms": 1.21,
#         "gap": 55,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.2 - south of the Kermadec Islands"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           179.574,
#           -33.7823,
#           7
#         ]
#       },
#       "id": "us7000gag3"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.6,
#         "place": "northern Qinghai, China",
#         "time": 1641577530809,
#         "updated": 1720268499007,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000g9zq",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000g9zq&format=geojson",
#         "felt": 14,
#         "cdi": 8.5,
#         "mmi": 8.434,
#         "alert": "orange",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 1012,
#         "net": "us",
#         "code": "7000g9zq",
#         "ids": ",us7000g9zq,usauto7000g9zq,at00r5cpbx,pt22007000,",
#         "sources": ",us,usauto,at,pt,",
#         "types": ",dyfi,finite-fault,general-text,ground-failure,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 2.685,
#         "rms": 0.69,
#         "gap": 13,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.6 - northern Qinghai, China"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           101.29,
#           37.8283,
#           13
#         ]
#       },
#       "id": "us7000g9zq"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.1,
#         "place": "near the coast of Nicaragua",
#         "time": 1641486305973,
#         "updated": 1650528145242,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000g9nb",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000g9nb&format=geojson",
#         "felt": 56,
#         "cdi": 4.4,
#         "mmi": 4.644,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 597,
#         "net": "us",
#         "code": "7000g9nb",
#         "ids": ",us7000g9nb,usauto7000g9nb,at00r5aqxv,pt22006001,",
#         "sources": ",us,usauto,at,pt,",
#         "types": ",dyfi,ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 0.732,
#         "rms": 1.24,
#         "gap": 43,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.1 - near the coast of Nicaragua"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -87.1371,
#           11.9367,
#           17
#         ]
#       },
#       "id": "us7000g9nb"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6,
#         "place": "284 km E of Katabu, Indonesia",
#         "time": 1641329746858,
#         "updated": 1647123547040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000g90c",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000g90c&format=geojson",
#         "felt": 1,
#         "cdi": 5.4,
#         "mmi": 1.989,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 554,
#         "net": "us",
#         "code": "7000g90c",
#         "ids": ",us7000g90c,usauto7000g90c,pt22004053,",
#         "sources": ",us,usauto,pt,",
#         "types": ",dyfi,ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 4.393,
#         "rms": 0.99,
#         "gap": 10,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.0 - 284 km E of Katabu, Indonesia"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           125.0808,
#           -4.8065,
#           544
#         ]
#       },
#       "id": "us7000g90c"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.2,
#         "place": "66 km E of Hualien City, Taiwan",
#         "time": 1641203195767,
#         "updated": 1671078335010,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000g8n3",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000g8n3&format=geojson",
#         "felt": 66,
#         "cdi": 5.6,
#         "mmi": 4.212,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 628,
#         "net": "us",
#         "code": "7000g8n3",
#         "ids": ",us7000g8n3,usauto7000g8n3,pt22003001,",
#         "sources": ",us,usauto,pt,",
#         "types": ",dyfi,ground-failure,impact-text,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 0.629,
#         "rms": 0.9,
#         "gap": 66,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.2 - 66 km E of Hualien City, Taiwan"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           122.2592,
#           24.0079,
#           19
#         ]
#       },
#       "id": "us7000g8n3"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6,
#         "place": "110 km NW of Sola, Vanuatu",
#         "time": 1641175784647,
#         "updated": 1647123542040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000g8kq",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000g8kq&format=geojson",
#         "felt": 2,
#         "cdi": 3.8,
#         "mmi": 4.421,
#         "alert": "green",
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 555,
#         "net": "us",
#         "code": "7000g8kq",
#         "ids": ",us7000g8kq,usauto7000g8kq,pt22003000,",
#         "sources": ",us,usauto,pt,",
#         "types": ",dyfi,ground-failure,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,",
#         "nst": null,
#         "dmin": 2.278,
#         "rms": 1.18,
#         "gap": 33,
#         "magType": "mww",
#         "type": "earthquake",
#         "title": "M 6.0 - 110 km NW of Sola, Vanuatu"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           166.8148,
#           -13.1864,
#           104
#         ]
#       },
#       "id": "us7000g8kq"
#     }
#   ],
#   "bbox": [
#     -176.7217,
#     -55.3696,
#     6.2,
#     179.574,
#     53.2402,
#     544
#   ]
# }

# %% [markdown]
# #### Let's be a little more selective now.
# - go find the documentation, figure out how to specifiy a location
# - pick a place, such as Alaksa, and define the region
# - run it again!
# https://www.mapsofworld.com/usa/states/alaska/lat-long.html

# %%
response = requests.get("https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2022-01-01&endtime=2022-01-31&latitude=-33&longitude=-70&maxradius=1")
json_response = response.json()
formatted_json = json.dumps(json_response, sort_keys=False, indent=2)
print(formatted_json)
# Out:
# {
#   "type": "FeatureCollection",
#   "metadata": {
#     "generated": 1761688801000,
#     "url": "https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2022-01-01&endtime=2022-01-31&latitude=-33&longitude=-70&maxradius=1",
#     "title": "USGS Earthquakes",
#     "status": 200,
#     "api": "1.14.1",
#     "count": 2
#   },
#   "features": [
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 3.3,
#         "place": "17 km ENE of Puente Alto, Chile",
#         "time": 1643423014333,
#         "updated": 1650045421040,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gg3p",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gg3p&format=geojson",
#         "felt": 1,
#         "cdi": 2,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 168,
#         "net": "us",
#         "code": "7000gg3p",
#         "ids": ",us7000gg3p,",
#         "sources": ",us,",
#         "types": ",dyfi,origin,phase-data,",
#         "nst": null,
#         "dmin": 0.108,
#         "rms": 0.25,
#         "gap": 162,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 3.3 - 17 km ENE of Puente Alto, Chile"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -70.4013,
#           -33.5527,
#           16.98
#         ]
#       },
#       "id": "us7000gg3p"
#     },
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 4,
#         "place": "18 km SSE of Llaillay, Chile",
#         "time": 1641829348106,
#         "updated": 1659796748148,
#         "tz": null,
#         "url": "https://earthquake.usgs.gov/earthquakes/eventpage/us7000gajq",
#         "detail": "https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000gajq&format=geojson",
#         "felt": 20,
#         "cdi": 3.8,
#         "mmi": null,
#         "alert": null,
#         "status": "reviewed",
#         "tsunami": 0,
#         "sig": 254,
#         "net": "us",
#         "code": "7000gajq",
#         "ids": ",us7000gajq,",
#         "sources": ",us,",
#         "types": ",dyfi,origin,phase-data,",
#         "nst": null,
#         "dmin": 0.225,
#         "rms": 0.29,
#         "gap": 80,
#         "magType": "ml",
#         "type": "earthquake",
#         "title": "M 4.0 - 18 km SSE of Llaillay, Chile"
#       },
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -70.8799,
#           -32.9984,
#           73.37
#         ]
#       },
#       "id": "us7000gajq"
#     }
#   ],
#   "bbox": [
#     -70.8799,
#     -33.5527,
#     16.98,
#     -70.4013,
#     -32.9984,
#     73.37
#   ]
# }

# %% [markdown]
# #### Getting what we need...
# Now, we will *print the place, date, and magnitude of each of them*
#
# Here is what we used:
# ```json
# "features": [
#     {
#       "type": "Feature",
#       "properties": {
#         "mag": 6.2,
#         "place": "66 km E of Hualien City, Taiwan",
#         "time": 1641203195767,
# ...
# ```

# %% [markdown]
# You've already worked with iteration, let's use that with our json.  We want to to iterate through each earthquake observation, print some stuff, and at the end, print the maximum magnitude.  I'll get you started...

# %%
max_magnitude = 0

for earthquake in json_response["features"]:
  # get the magnitude
  print()
  # print some stuff

  # update our max on record as needed

# print the max
# Out:
#   File "/tmp/ipython-input-3011901782.py", line 10
#     # print the max
#                    ^
# SyntaxError: incomplete input
